# %%
import pandas as pd
from matplotlib import pyplot as plt
import datetime as dt
import pymongo

# %%
#Read in the CSV Data
data = pd.read_csv('Resources/311_Call_Center_Service_Requests.csv')
data.head()
# Out:
# C:\Users\bjros\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       CASE ID SOURCE            DEPARTMENT  \
# 0  2019205916  PHONE                   NHS
# 1  2020004802    WEB  City Managers Office
# 2  2019193105  PHONE          Public Works
# 3  2019193330  PHONE        Water Services
# 4  2019197893    WEB        Water Services
#
#                                       WORK GROUP  \
# 0                               NHS-Solid Waste-
# 1   City Managers Office-311 Call Center-Support
# 2  Public Works-Capital Projects-Traffic Control
# 3     Water Services-Line Maintenance-Stormwater
# 4       Water Services-Meter and Field Services-
#
#                                         REQUEST TYPE  \
# 0  Trash / Recycling-Trash Collection-Missed by City
# 1  Streets/Roadways/Alleys-Snow / Ice-Snow Verify...
# 2                Signs-Traffic Sign-New Sign Request
# 3              Stormwater-Stormwater Referral-Repair
# 4                               Water-Leak-In Street
#
#                       CATEGORY                  TYPE                   DETAIL  \
# 0            Trash / Recycling      Trash Collection           Missed by City
# 1  Streets / Roadways / Alleys            Snow / Ice  Snow Route Verification
# 2                        Signs          Traffic Sign         New Sign Request
# 3          Storm Water / Sewer  Storm Water Referral                   Repair
# 4                        Water                  Leak                In Street
#
#   CREATION DATE CREATION TIME  ...  ZIP CODE               NEIGHBORHOOD  \
# 0    12/18/2019      01:52 PM  ...   64124.0         Independence Plaza
# 1    01/12/2020      03:37 PM  ...   64119.0  Gracemor-Randolph Corners
# 2    11/15/2019      03:01 PM  ...   64111.0             Plaza Westport
# 3    11/16/2019      01:16 PM  ...   64113.0               Ward Estates
# 4    11/27/2019      04:01 PM  ...   64110.0                  Crestwood
#
#     COUNTY COUNCIL DISTRICT POLICE DISTRICT  PARCEL ID NO   LATITUDE  \
# 0  Jackson              3.0            East         10639  39.102651
# 1     Clay              1.0     Shoal Creek         89209  39.196584
# 2  Jackson              4.0         Central        233668  39.045500
# 3  Jackson              4.0           Metro        143005  39.027698
# 4  Jackson              4.0           Metro        143361  39.031266
#
#    LONGITUDE                                           CASE URL  \
# 0 -94.546809  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1 -94.487959  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2 -94.590528  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3 -94.599931  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4 -94.581718  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#   30-60-90 Days Open Window
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 30 columns]

# %%
#Count the Rows of Each Column
row_count = data.count()
row_count
# Out:
# CASE ID                      1467984
# SOURCE                       1467936
# DEPARTMENT                   1467984
# WORK GROUP                   1467984
# REQUEST TYPE                 1467984
# CATEGORY                     1467984
# TYPE                         1467984
# DETAIL                       1467984
# CREATION DATE                1467984
# CREATION TIME                1467984
# CREATION MONTH               1467984
# CREATION YEAR                1467984
# STATUS                       1467984
# EXCEEDED EST TIMEFRAME       1467965
# CLOSED DATE                  1449220
# CLOSED MONTH                 1435665
# CLOSED YEAR                  1435665
# DAYS TO CLOSE                1435665
# STREET ADDRESS               1467960
# ADDRESS WITH GEOCODE         1467984
# ZIP CODE                     1467160
# NEIGHBORHOOD                 1422568
# COUNTY                       1401033
# COUNCIL DISTRICT             1432750
# POLICE DISTRICT              1432727
# PARCEL ID NO                 1467984
# LATITUDE                     1467984
# LONGITUDE                    1467984
# CASE URL                     1467984
# 30-60-90 Days Open Window      18764
# dtype: int64

# %%
#Parse the Day & Month from the Date
listy = []
#Loop through the 'CREATION DATE' data
for i in range(len(data['CREATION DATE'])):
    #Use Split Function to Pull Out the Month & Day Values for Each Record
    months = data['CREATION DATE'][i].split("/")[0]
    days = data['CREATION DATE'][i].split("/")[1]
    #Concatenate the Values
    month_days = str(months) + "/" + str(days)
    #Append Month/Day Value to List
    listy.append(month_days)
#Create a New Series to Unpack the Month/Day Values
data['CREATION MONTH-DAY'] = pd.Series(listy)
data
# Out:
#             CASE ID SOURCE                     DEPARTMENT  \
# 0        2019205916  PHONE                            NHS
# 1        2020004802    WEB           City Managers Office
# 2        2019193105  PHONE                   Public Works
# 3        2019193330  PHONE                 Water Services
# 4        2019197893    WEB                 Water Services
# ...             ...    ...                            ...
# 1467979  2019171612  EMAIL  City Planning and Development
# 1467980  2019172540    BOT                            NHS
# 1467981  2019171704  PHONE                  Parks and Rec
# 1467982  2019170637  PHONE                            NHS
# 1467983  2019172835  PHONE                   Public Works
#
#                                                WORK GROUP  \
# 0                                        NHS-Solid Waste-
# 1            City Managers Office-311 Call Center-Support
# 2           Public Works-Capital Projects-Traffic Control
# 3              Water Services-Line Maintenance-Stormwater
# 4                Water Services-Meter and Field Services-
# ...                                                   ...
# 1467979  City Planning and Development-Permit Compliance-
# 1467980                                  NHS-Solid Waste-
# 1467981    Parks and Rec-Landscape Services-Forestry Tech
# 1467982           NHS-Neighborhood Preservation-Abatement
# 1467983     Public Works-Capital Projects-Traffic Signals
#
#                                               REQUEST TYPE  \
# 0        Trash / Recycling-Trash Collection-Missed by City
# 1        Streets/Roadways/Alleys-Snow / Ice-Snow Verify...
# 2                      Signs-Traffic Sign-New Sign Request
# 3                    Stormwater-Stormwater Referral-Repair
# 4                                     Water-Leak-In Street
# ...                                                    ...
# 1467979  Prop/Build/Construct-Construction Issue/Concer...
# 1467980  Trash / Recycling-Trash Collection-Missed by C...
# 1467981             Trees-Services-Plant City Tree Request
# 1467982           Mowing / Weeds-Public Property-Land Bank
# 1467983         Lights / Signals-Traffic Signal-Signal out
#
#                                     CATEGORY                        TYPE  \
# 0                          Trash / Recycling            Trash Collection
# 1                Streets / Roadways / Alleys                  Snow / Ice
# 2                                      Signs                Traffic Sign
# 3                        Storm Water / Sewer        Storm Water Referral
# 4                                      Water                        Leak
# ...                                      ...                         ...
# 1467979  Property / Buildings / Construction  Construction Issue/Concern
# 1467980                    Trash / Recycling            Trash Collection
# 1467981                                Trees                    Services
# 1467982                       Mowing / Weeds             Public Property
# 1467983                     Lights / Signals              Traffic Signal
#
#                              DETAIL CREATION DATE CREATION TIME  ...  \
# 0                    Missed by City    12/18/2019      01:52 PM  ...
# 1           Snow Route Verification    01/12/2020      03:37 PM  ...
# 2                  New Sign Request    11/15/2019      03:01 PM  ...
# 3                            Repair    11/16/2019      01:16 PM  ...
# 4                         In Street    11/27/2019      04:01 PM  ...
# ...                             ...           ...           ...  ...
# 1467979                       Other    09/25/2019      06:17 PM  ...
# 1467980  Missed by Contractor South    09/27/2019      11:48 AM  ...
# 1467981     Plant City Tree Request    09/26/2019      08:05 AM  ...
# 1467982                   Land Bank    09/24/2019      01:19 PM  ...
# 1467983                  Signal Out    09/27/2019      06:33 PM  ...
#
#                       NEIGHBORHOOD   COUNTY COUNCIL DISTRICT POLICE DISTRICT  \
# 0               Independence Plaza  Jackson              3.0            East
# 1        Gracemor-Randolph Corners     Clay              1.0     Shoal Creek
# 2                   Plaza Westport  Jackson              4.0         Central
# 3                     Ward Estates  Jackson              4.0           Metro
# 4                        Crestwood  Jackson              4.0           Metro
# ...                            ...      ...              ...             ...
# 1467979                Shoal Creek     Clay              1.0     Shoal Creek
# 1467980              Hickman Mills  Jackson              6.0           South
# 1467981             Scarritt Point  Jackson              4.0            East
# 1467982      North Town Fork Creek  Jackson              5.0           Metro
# 1467983                 Woodbridge  Jackson              6.0           South
#
#         PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0              10639  39.102651 -94.546809
# 1              89209  39.196584 -94.487959
# 2             233668  39.045500 -94.590528
# 3             143005  39.027698 -94.599931
# 4             143361  39.031266 -94.581718
# ...              ...        ...        ...
# 1467979        98792  39.296232 -94.478623
# 1467980        74726  38.915583 -94.521257
# 1467981        40391  39.116513 -94.537826
# 1467982        36118  39.033313 -94.554381
# 1467983       158980  38.890659 -94.594038
#
#                                                   CASE URL  \
# 0        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# ...                                                    ...
# 1467979  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467980  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467981  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467982  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467983  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#         30-60-90 Days Open Window CREATION MONTH-DAY
# 0                             NaN              12/18
# 1                             NaN              01/12
# 2                             NaN              11/15
# 3                             NaN              11/16
# 4                             NaN              11/27
# ...                           ...                ...
# 1467979                       NaN              09/25
# 1467980                       NaN              09/27
# 1467981                       NaN              09/26
# 1467982                       NaN              09/24
# 1467983                       NaN              09/27
#
# [1467984 rows x 31 columns]

# %%
#Reformat the 'CREATION DATE' Column
listy1 = []
#Loop through the 'CREATION DATE' data
for i in range(len(data['CREATION DATE'])):
    #Use Split Function to Pull Out the Month & Day Values for Each Record
    months1 = data['CREATION DATE'][i].split("/")[0]
    days1 = data['CREATION DATE'][i].split("/")[1]
    years1 = data['CREATION DATE'][i].split("/")[2]
    #Concatenate the Values
    years_month_days = str(years1) + "/" + str(months1) + "/" + str(days1)
    #Append Month/Day Value to List
    listy1.append(years_month_days)
#Create a New Series to Unpack the Year/Month/Day Values
data['CREATION YEAR-MONTH-DAY'] = pd.Series(listy1)
data
# Out:
#             CASE ID SOURCE                     DEPARTMENT  \
# 0        2019205916  PHONE                            NHS
# 1        2020004802    WEB           City Managers Office
# 2        2019193105  PHONE                   Public Works
# 3        2019193330  PHONE                 Water Services
# 4        2019197893    WEB                 Water Services
# ...             ...    ...                            ...
# 1467979  2019171612  EMAIL  City Planning and Development
# 1467980  2019172540    BOT                            NHS
# 1467981  2019171704  PHONE                  Parks and Rec
# 1467982  2019170637  PHONE                            NHS
# 1467983  2019172835  PHONE                   Public Works
#
#                                                WORK GROUP  \
# 0                                        NHS-Solid Waste-
# 1            City Managers Office-311 Call Center-Support
# 2           Public Works-Capital Projects-Traffic Control
# 3              Water Services-Line Maintenance-Stormwater
# 4                Water Services-Meter and Field Services-
# ...                                                   ...
# 1467979  City Planning and Development-Permit Compliance-
# 1467980                                  NHS-Solid Waste-
# 1467981    Parks and Rec-Landscape Services-Forestry Tech
# 1467982           NHS-Neighborhood Preservation-Abatement
# 1467983     Public Works-Capital Projects-Traffic Signals
#
#                                               REQUEST TYPE  \
# 0        Trash / Recycling-Trash Collection-Missed by City
# 1        Streets/Roadways/Alleys-Snow / Ice-Snow Verify...
# 2                      Signs-Traffic Sign-New Sign Request
# 3                    Stormwater-Stormwater Referral-Repair
# 4                                     Water-Leak-In Street
# ...                                                    ...
# 1467979  Prop/Build/Construct-Construction Issue/Concer...
# 1467980  Trash / Recycling-Trash Collection-Missed by C...
# 1467981             Trees-Services-Plant City Tree Request
# 1467982           Mowing / Weeds-Public Property-Land Bank
# 1467983         Lights / Signals-Traffic Signal-Signal out
#
#                                     CATEGORY                        TYPE  \
# 0                          Trash / Recycling            Trash Collection
# 1                Streets / Roadways / Alleys                  Snow / Ice
# 2                                      Signs                Traffic Sign
# 3                        Storm Water / Sewer        Storm Water Referral
# 4                                      Water                        Leak
# ...                                      ...                         ...
# 1467979  Property / Buildings / Construction  Construction Issue/Concern
# 1467980                    Trash / Recycling            Trash Collection
# 1467981                                Trees                    Services
# 1467982                       Mowing / Weeds             Public Property
# 1467983                     Lights / Signals              Traffic Signal
#
#                              DETAIL CREATION DATE CREATION TIME  ...   COUNTY  \
# 0                    Missed by City    12/18/2019      01:52 PM  ...  Jackson
# 1           Snow Route Verification    01/12/2020      03:37 PM  ...     Clay
# 2                  New Sign Request    11/15/2019      03:01 PM  ...  Jackson
# 3                            Repair    11/16/2019      01:16 PM  ...  Jackson
# 4                         In Street    11/27/2019      04:01 PM  ...  Jackson
# ...                             ...           ...           ...  ...      ...
# 1467979                       Other    09/25/2019      06:17 PM  ...     Clay
# 1467980  Missed by Contractor South    09/27/2019      11:48 AM  ...  Jackson
# 1467981     Plant City Tree Request    09/26/2019      08:05 AM  ...  Jackson
# 1467982                   Land Bank    09/24/2019      01:19 PM  ...  Jackson
# 1467983                  Signal Out    09/27/2019      06:33 PM  ...  Jackson
#
#          COUNCIL DISTRICT POLICE DISTRICT PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0                     3.0            East        10639  39.102651 -94.546809
# 1                     1.0     Shoal Creek        89209  39.196584 -94.487959
# 2                     4.0         Central       233668  39.045500 -94.590528
# 3                     4.0           Metro       143005  39.027698 -94.599931
# 4                     4.0           Metro       143361  39.031266 -94.581718
# ...                   ...             ...          ...        ...        ...
# 1467979               1.0     Shoal Creek        98792  39.296232 -94.478623
# 1467980               6.0           South        74726  38.915583 -94.521257
# 1467981               4.0            East        40391  39.116513 -94.537826
# 1467982               5.0           Metro        36118  39.033313 -94.554381
# 1467983               6.0           South       158980  38.890659 -94.594038
#
#                                                   CASE URL  \
# 0        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# ...                                                    ...
# 1467979  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467980  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467981  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467982  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467983  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#         30-60-90 Days Open Window CREATION MONTH-DAY CREATION YEAR-MONTH-DAY
# 0                             NaN              12/18              2019/12/18
# 1                             NaN              01/12              2020/01/12
# 2                             NaN              11/15              2019/11/15
# 3                             NaN              11/16              2019/11/16
# 4                             NaN              11/27              2019/11/27
# ...                           ...                ...                     ...
# 1467979                       NaN              09/25              2019/09/25
# 1467980                       NaN              09/27              2019/09/27
# 1467981                       NaN              09/26              2019/09/26
# 1467982                       NaN              09/24              2019/09/24
# 1467983                       NaN              09/27              2019/09/27
#
# [1467984 rows x 32 columns]

# %%
#Create Column with Concatenated Values for Creation Date-Time
data['CREATION DATE-TIME'] = data['CREATION YEAR-MONTH-DAY'] + " " + data['CREATION TIME']
data
# Out:
#             CASE ID SOURCE                     DEPARTMENT  \
# 0        2019205916  PHONE                            NHS
# 1        2020004802    WEB           City Managers Office
# 2        2019193105  PHONE                   Public Works
# 3        2019193330  PHONE                 Water Services
# 4        2019197893    WEB                 Water Services
# ...             ...    ...                            ...
# 1467979  2019171612  EMAIL  City Planning and Development
# 1467980  2019172540    BOT                            NHS
# 1467981  2019171704  PHONE                  Parks and Rec
# 1467982  2019170637  PHONE                            NHS
# 1467983  2019172835  PHONE                   Public Works
#
#                                                WORK GROUP  \
# 0                                        NHS-Solid Waste-
# 1            City Managers Office-311 Call Center-Support
# 2           Public Works-Capital Projects-Traffic Control
# 3              Water Services-Line Maintenance-Stormwater
# 4                Water Services-Meter and Field Services-
# ...                                                   ...
# 1467979  City Planning and Development-Permit Compliance-
# 1467980                                  NHS-Solid Waste-
# 1467981    Parks and Rec-Landscape Services-Forestry Tech
# 1467982           NHS-Neighborhood Preservation-Abatement
# 1467983     Public Works-Capital Projects-Traffic Signals
#
#                                               REQUEST TYPE  \
# 0        Trash / Recycling-Trash Collection-Missed by City
# 1        Streets/Roadways/Alleys-Snow / Ice-Snow Verify...
# 2                      Signs-Traffic Sign-New Sign Request
# 3                    Stormwater-Stormwater Referral-Repair
# 4                                     Water-Leak-In Street
# ...                                                    ...
# 1467979  Prop/Build/Construct-Construction Issue/Concer...
# 1467980  Trash / Recycling-Trash Collection-Missed by C...
# 1467981             Trees-Services-Plant City Tree Request
# 1467982           Mowing / Weeds-Public Property-Land Bank
# 1467983         Lights / Signals-Traffic Signal-Signal out
#
#                                     CATEGORY                        TYPE  \
# 0                          Trash / Recycling            Trash Collection
# 1                Streets / Roadways / Alleys                  Snow / Ice
# 2                                      Signs                Traffic Sign
# 3                        Storm Water / Sewer        Storm Water Referral
# 4                                      Water                        Leak
# ...                                      ...                         ...
# 1467979  Property / Buildings / Construction  Construction Issue/Concern
# 1467980                    Trash / Recycling            Trash Collection
# 1467981                                Trees                    Services
# 1467982                       Mowing / Weeds             Public Property
# 1467983                     Lights / Signals              Traffic Signal
#
#                              DETAIL CREATION DATE CREATION TIME  ...  \
# 0                    Missed by City    12/18/2019      01:52 PM  ...
# 1           Snow Route Verification    01/12/2020      03:37 PM  ...
# 2                  New Sign Request    11/15/2019      03:01 PM  ...
# 3                            Repair    11/16/2019      01:16 PM  ...
# 4                         In Street    11/27/2019      04:01 PM  ...
# ...                             ...           ...           ...  ...
# 1467979                       Other    09/25/2019      06:17 PM  ...
# 1467980  Missed by Contractor South    09/27/2019      11:48 AM  ...
# 1467981     Plant City Tree Request    09/26/2019      08:05 AM  ...
# 1467982                   Land Bank    09/24/2019      01:19 PM  ...
# 1467983                  Signal Out    09/27/2019      06:33 PM  ...
#
#          COUNCIL DISTRICT  POLICE DISTRICT PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0                     3.0             East        10639  39.102651 -94.546809
# 1                     1.0      Shoal Creek        89209  39.196584 -94.487959
# 2                     4.0          Central       233668  39.045500 -94.590528
# 3                     4.0            Metro       143005  39.027698 -94.599931
# 4                     4.0            Metro       143361  39.031266 -94.581718
# ...                   ...              ...          ...        ...        ...
# 1467979               1.0      Shoal Creek        98792  39.296232 -94.478623
# 1467980               6.0            South        74726  38.915583 -94.521257
# 1467981               4.0             East        40391  39.116513 -94.537826
# 1467982               5.0            Metro        36118  39.033313 -94.554381
# 1467983               6.0            South       158980  38.890659 -94.594038
#
#                                                   CASE URL  \
# 0        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4        http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# ...                                                    ...
# 1467979  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467980  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467981  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467982  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467983  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#          30-60-90 Days Open Window CREATION MONTH-DAY CREATION YEAR-MONTH-DAY  \
# 0                              NaN              12/18              2019/12/18
# 1                              NaN              01/12              2020/01/12
# 2                              NaN              11/15              2019/11/15
# 3                              NaN              11/16              2019/11/16
# 4                              NaN              11/27              2019/11/27
# ...                            ...                ...                     ...
# 1467979                        NaN              09/25              2019/09/25
# 1467980                        NaN              09/27              2019/09/27
# 1467981                        NaN              09/26              2019/09/26
# 1467982                        NaN              09/24              2019/09/24
# 1467983                        NaN              09/27              2019/09/27
#
#           CREATION DATE-TIME
# 0        2019/12/18 01:52 PM
# 1        2020/01/12 03:37 PM
# 2        2019/11/15 03:01 PM
# 3        2019/11/16 01:16 PM
# 4        2019/11/27 04:01 PM
# ...                      ...
# 1467979  2019/09/25 06:17 PM
# 1467980  2019/09/27 11:48 AM
# 1467981  2019/09/26 08:05 AM
# 1467982  2019/09/24 01:19 PM
# 1467983  2019/09/27 06:33 PM
#
# [1467984 rows x 33 columns]

# %%
#Sort the Values by Creation Date-Time
data = data.sort_values('CREATION DATE-TIME', ascending=False).reset_index(drop=True)
data
# Out:
#             CASE ID SOURCE                     DEPARTMENT  \
# 0        2020070028  PHONE                            NHS
# 1        2020070027  PHONE                 Water Services
# 2        2020070025  PHONE                 Water Services
# 3        2020070021  PHONE                            NHS
# 4        2020070019  PHONE                   Public Works
# ...             ...    ...                            ...
# 1467979  2007000101  PHONE                   Public Works
# 1467980  2007000100  PHONE                   Public Works
# 1467981  2007000099  PHONE                            NHS
# 1467982  2006000004  PHONE  City Planning and Development
# 1467983  2006000002  PHONE                            NHS
#
#                                                WORK GROUP  \
# 0                           NHS-Animal Health and Safety-
# 1                Water Services-Meter and Field Services-
# 2                   Water Services-Engineering-Stormwater
# 3                          NHS-Solid Waste-Administration
# 4                     Public Works-Capital Projects-Signs
# ...                                                   ...
# 1467979        Public Works-Street and Traffic-District 3
# 1467980        Public Works-Street and Traffic-District 3
# 1467981                    NHS-Neighborhood Preservation-
# 1467982  City Planning and Development-Permit Compliance-
# 1467983                    NHS-Neighborhood Preservation-
#
#                                               REQUEST TYPE  \
# 0                          Animals / Pets-Wildlife-Injured
# 1                                       Water-Leak-Hydrant
# 2                 Capital Projects-Storm Water-Engineering
# 3        Trash / Recycling-Services-Service Issue / Pro...
# 4                          Signs-Street Name Signs-Missing
# ...                                                    ...
# 1467979                     Pothole (South of 47th Street)
# 1467980       Snow or Ice on Street (South of 47th Street)
# 1467981                   Property and Nuisance Violations
# 1467982                  Zoning Inspections and Violations
# 1467983                                Nuisance Violations
#
#                                CATEGORY               TYPE  \
# 0                        Animals / Pets           Wildlife
# 1                                 Water               Leak
# 2                      Capital Projects        Storm Water
# 3                     Trash / Recycling           Services
# 4                                 Signs  Street Name Signs
# ...                                 ...                ...
# 1467979                         Pothole             Street
# 1467980                      Snow & Ice             Street
# 1467981  Property & Nuisance Violations   Private Property
# 1467982                          Zoning      Investigation
# 1467983             Nuisance Violations   Private Property
#
#                           DETAIL CREATION DATE CREATION TIME  ...  \
# 0                        Injured    05/20/2020      09:26 AM  ...
# 1                        Hydrant    05/20/2020      09:23 AM  ...
# 2                    Engineering    05/20/2020      09:22 AM  ...
# 3        Service Issue / Problem    05/20/2020      09:21 AM  ...
# 4                        Missing    05/20/2020      09:20 AM  ...
# ...                          ...           ...           ...  ...
# 1467979           District Three    01/04/2007      01:07 PM  ...
# 1467980           District Three    01/04/2007      01:06 PM  ...
# 1467981                      All    01/04/2007      01:02 PM  ...
# 1467982                      All    01/03/2007      01:26 PM  ...
# 1467983                      All    12/29/2006      01:47 PM  ...
#
#          COUNCIL DISTRICT  POLICE DISTRICT PARCEL ID NO   LATITUDE  \
# 0                     1.0      Shoal Creek        86906  39.192537
# 1                     3.0            Metro        50804  39.033228
# 2                     2.0      Shoal Creek       227086  39.260214
# 3                     2.0            North       164685  39.214514
# 4                     6.0            Metro       106807  39.014424
# ...                   ...              ...          ...        ...
# 1467979               NaN              NaN            0  35.797519
# 1467980               NaN              NaN            0  35.797519
# 1467981               6.0            South        72375  38.921898
# 1467982               NaN              NaN            0  35.797519
# 1467983               NaN              NaN            0  35.797519
#
#           LONGITUDE                                           CASE URL  \
# 0        -94.559330  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1        -94.493439  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2        -94.561275  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3        -94.611094  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4        -94.589893  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# ...             ...                                                ...
# 1467979 -103.890579  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467980 -103.890579  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467981  -94.501380  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467982 -103.890579  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1467983 -103.890579  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#          30-60-90 Days Open Window CREATION MONTH-DAY CREATION YEAR-MONTH-DAY  \
# 0                              0.0              05/20              2020/05/20
# 1                              0.0              05/20              2020/05/20
# 2                              0.0              05/20              2020/05/20
# 3                              0.0              05/20              2020/05/20
# 4                              0.0              05/20              2020/05/20
# ...                            ...                ...                     ...
# 1467979                        NaN              01/04              2007/01/04
# 1467980                        NaN              01/04              2007/01/04
# 1467981                        NaN              01/04              2007/01/04
# 1467982                        NaN              01/03              2007/01/03
# 1467983                        NaN              12/29              2006/12/29
#
#           CREATION DATE-TIME
# 0        2020/05/20 09:26 AM
# 1        2020/05/20 09:23 AM
# 2        2020/05/20 09:22 AM
# 3        2020/05/20 09:21 AM
# 4        2020/05/20 09:20 AM
# ...                      ...
# 1467979  2007/01/04 01:07 PM
# 1467980  2007/01/04 01:06 PM
# 1467981  2007/01/04 01:02 PM
# 1467982  2007/01/03 01:26 PM
# 1467983  2006/12/29 01:47 PM
#
# [1467984 rows x 33 columns]

# %%
#Change Data Type of 'DAYS TO CLOSE' Column
#Found Method to Replace Values from Strings at https://stackoverflow.com/questions/37919479/removing-characters-from-a-string-in-pandas
data['DAYS TO CLOSE'] = data['DAYS TO CLOSE'].str.replace(",", "")
data['DAYS TO CLOSE'] = data['DAYS TO CLOSE'].astype(float)
data['DAYS TO CLOSE'].dtype
# Out:
# dtype('float64')

# %%
## Perform Check to Verify that Newest Data is Available
data.loc[data['CREATION DATE'] == '05/20/2020']
# Out:
#        CASE ID SOURCE      DEPARTMENT  \
# 0   2020070028  PHONE             NHS
# 1   2020070027  PHONE  Water Services
# 2   2020070025  PHONE  Water Services
# 3   2020070021  PHONE             NHS
# 4   2020070019  PHONE    Public Works
# 5   2020070013  PHONE             NHS
# 6   2020070014  PHONE  Water Services
# 7   2020070009  PHONE    Public Works
# 8   2020070011  PHONE             NHS
# 9   2020070007  PHONE             NHS
# 10  2020070005  PHONE             NHS
# 11  2020070003  PHONE          Health
# 12  2020070004  PHONE             NHS
# 13  2020070002  PHONE            KCPD
# 14  2020070000  PHONE             NHS
# 15  2020069998  PHONE             NHS
# 16  2020069996  PHONE             NHS
# 17  2020069995  PHONE            KCPD
# 18  2020069994  PHONE             NHS
# 19  2020069993  PHONE             NHS
# 20  2020069990  PHONE             NHS
# 21  2020069988  PHONE    Public Works
# 22  2020069986  EMAIL             NHS
# 23  2020069983  PHONE   Parks and Rec
# 24  2020069981    BOT             NHS
# 25  2020069980  PHONE    Public Works
# 26  2020069977  PHONE             NHS
# 27  2020069974  PHONE  Water Services
# 28  2020069975  PHONE             NHS
# 29  2020069969  PHONE             NHS
# 30  2020069968  PHONE             NHS
# 31  2020069966  PHONE            KCPD
# 32  2020069961  PHONE             NHS
# 33  2020069960  PHONE             NHS
# 34  2020069959   TWIR    Public Works
# 35  2020069954  PHONE    Public Works
# 36  2020069951  PHONE             NHS
# 37  2020069949  PHONE             NHS
# 38  2020069948  PHONE             NHS
# 39  2020069947  PHONE             NHS
# 40  2020069945  PHONE    Public Works
# 41  2020069939  PHONE    Public Works
#
#                                        WORK GROUP  \
# 0                   NHS-Animal Health and Safety-
# 1        Water Services-Meter and Field Services-
# 2           Water Services-Engineering-Stormwater
# 3                  NHS-Solid Waste-Administration
# 4             Public Works-Capital Projects-Signs
# 5                   NHS-Animal Health and Safety-
# 6           Water Services-Engineering-Stormwater
# 7    Public Works-Street and Traffic-Streetlights
# 8                                NHS-Solid Waste-
# 9                                NHS-Solid Waste-
# 10                               NHS-Solid Waste-
# 11                          Health-Healthy Homes-
# 12                 NHS-Neighborhood Preservation-
# 13                          KCPD-Parking Control-
# 14                 NHS-Neighborhood Preservation-
# 15                  NHS-Animal Health and Safety-
# 16                               NHS-Solid Waste-
# 17                          KCPD-Parking Control-
# 18                  NHS-Animal Health and Safety-
# 19        NHS-Neighborhood Preservation-Abatement
# 20                 NHS-Neighborhood Preservation-
# 21  Public Works-Capital Projects-Traffic Signals
# 22                 NHS-Neighborhood Preservation-
# 23      Parks and Rec-Landscape Services-Forestry
# 24                               NHS-Solid Waste-
# 25     Public Works-Street and Traffic-District 3
# 26                 NHS-Neighborhood Preservation-
# 27     Water Services-Line Maintenance-Wastewater
# 28                 NHS-Neighborhood Preservation-
# 29                 NHS-Neighborhood Preservation-
# 30                 NHS-Solid Waste-Administration
# 31                          KCPD-Parking Control-
# 32                 NHS-Solid Waste-Administration
# 33                               NHS-Solid Waste-
# 34   Public Works-Street and Traffic-Streetlights
# 35  Public Works-Capital Projects-Traffic Permits
# 36                 NHS-Solid Waste-Administration
# 37                 NHS-Neighborhood Preservation-
# 38                NHS-Solid Waste-Illegal Dumping
# 39        NHS-Neighborhood Preservation-Abatement
# 40  Public Works-Capital Projects-Traffic Permits
# 41            Public Works-Capital Projects-Signs
#
#                                          REQUEST TYPE  \
# 0                     Animals / Pets-Wildlife-Injured
# 1                                  Water-Leak-Hydrant
# 2            Capital Projects-Storm Water-Engineering
# 3   Trash / Recycling-Services-Service Issue / Pro...
# 4                     Signs-Street Name Signs-Missing
# 5                Animals / Pets-Bite-Animal on Animal
# 6            Capital Projects-Storm Water-Engineering
# 7   Lights / Signals-Street Light-Burning during t...
# 8   Trash / Recycling-Trash Collection-Missed by C...
# 9          Trash / Recycling-Recycling-Missed by City
# 10  Trash / Recycling-Trash Collection-Missed by City
# 11   Public Health-Services-Healthy Homes Information
# 12                                Property Violations
# 13         Vehicles / Parking-Abandoned On Street-Car
# 14                                Property Violations
# 15                     Animals / Pets-Wildlife-Inside
# 16                   Animals / Pets-Dead Animal -Curb
# 17         Vehicles / Parking-Abandoned On Street-Car
# 18      Animals / Pets-Cruelty or Neglect-Abandonment
# 19     Mowing / Weeds-Public Property-City Vacant Lot
# 20                                Property Violations
# 21         Lights / Signals-Traffic Signal-Signal out
# 22                                Property Violations
# 23                          Trees-Trimming-Tree Limbs
# 24  Trash / Recycling-Trash Collection-Missed by C...
# 25     Streets / Roadways / Alleys-Pothole-District 3
# 26                                Property Violations
# 27                  Sewer-Sewer Backup / Leak-Outside
# 28                                Property Violations
# 29                                Property Violations
# 30  Trash / Recycling-Services-Service Issue / Pro...
# 31         Vehicles / Parking-Abandoned On Street-Car
# 32       Trash / Recycling-Services-Call Back Request
# 33  Trash / Recycling-Trash Collection-Missed by C...
# 34    Lights / Signals-Street Light-Other Light Issue
# 35  Streets / Roadways / Alleys-Cut / Permit-Distr...
# 36  Trash / Recycling-Services-Service Issue / Pro...
# 37                                Property Violations
# 38           Trash / Recycling-Dumping-Camera Request
# 39    Trash / Recycling-Dumping-ROW Land Bank Central
# 40            Streets / Roadways / Alleys-Plate-Loose
# 41             Signs-Traffic Sign-Damaged – Emergency
#
#                                CATEGORY                  TYPE  \
# 0                        Animals / Pets              Wildlife
# 1                                 Water                  Leak
# 2                      Capital Projects           Storm Water
# 3                     Trash / Recycling              Services
# 4                                 Signs     Street Name Signs
# 5                        Animals / Pets                  Bite
# 6                      Capital Projects           Storm Water
# 7                      Lights / Signals          Street Light
# 8                     Trash / Recycling      Trash Collection
# 9                     Trash / Recycling             Recycling
# 10                    Trash / Recycling      Trash Collection
# 11                        Public Health              Services
# 12                       Mowing / Weeds  Private / Commercial
# 13                   Vehicles / Parking   Abandoned On Street
# 14                                Trees      Private Property
# 15                       Animals / Pets              Wildlife
# 16                       Animals / Pets           Dead Animal
# 17                   Vehicles / Parking   Abandoned On Street
# 18                       Animals / Pets    Cruelty or Neglect
# 19                       Mowing / Weeds       Public Property
# 20                       Mowing / Weeds  Private / Commercial
# 21                     Lights / Signals        Traffic Signal
# 22                       Mowing / Weeds  Private / Commercial
# 23                                Trees              Trimming
# 24                    Trash / Recycling      Trash Collection
# 25          Streets / Roadways / Alleys               Pothole
# 26                       Animals / Pets           Dead Animal
# 27                  Storm Water / Sewer   Sewer Backup / Leak
# 28                    Trash / Recycling              Nuisance
# 29  Property / Buildings / Construction  Property Maintenance
# 30                    Trash / Recycling              Services
# 31                   Vehicles / Parking   Abandoned On Street
# 32                    Trash / Recycling              Services
# 33                    Trash / Recycling      Trash Collection
# 34                     Lights / Signals          Street Light
# 35          Streets / Roadways / Alleys          Cut / Permit
# 36                    Trash / Recycling              Services
# 37  Property / Buildings / Construction  Property Maintenance
# 38                    Trash / Recycling               Dumping
# 39                    Trash / Recycling               Dumping
# 40          Streets / Roadways / Alleys                 Plate
# 41                                Signs          Traffic Sign
#
#                         DETAIL CREATION DATE CREATION TIME  ...  \
# 0                      Injured    05/20/2020      09:26 AM  ...
# 1                      Hydrant    05/20/2020      09:23 AM  ...
# 2                  Engineering    05/20/2020      09:22 AM  ...
# 3      Service Issue / Problem    05/20/2020      09:21 AM  ...
# 4                      Missing    05/20/2020      09:20 AM  ...
# 5             Animal on Animal    05/20/2020      09:17 AM  ...
# 6                  Engineering    05/20/2020      09:17 AM  ...
# 7       Burning During The Day    05/20/2020      09:15 AM  ...
# 8   Missed by Contractor South    05/20/2020      09:15 AM  ...
# 9               Missed by City    05/20/2020      09:12 AM  ...
# 10              Missed by City    05/20/2020      09:11 AM  ...
# 11   Healthy Homes Information    05/20/2020      09:09 AM  ...
# 12                Lot - Vacant    05/20/2020      09:09 AM  ...
# 13                         Car    05/20/2020      09:08 AM  ...
# 14                 Tree Debris    05/20/2020      09:05 AM  ...
# 15                      Inside    05/20/2020      09:00 AM  ...
# 16                        Curb    05/20/2020      08:58 AM  ...
# 17                         Car    05/20/2020      08:57 AM  ...
# 18                 Abandonment    05/20/2020      08:56 AM  ...
# 19             City Vacant Lot    05/20/2020      08:53 AM  ...
# 20             Lot - Structure    05/20/2020      08:49 AM  ...
# 21                  Signal Out    05/20/2020      08:46 AM  ...
# 22             Lot - Structure    05/20/2020      08:44 AM  ...
# 23                  Tree Limbs    05/20/2020      08:42 AM  ...
# 24  Missed by Contractor North    05/20/2020      08:40 AM  ...
# 25                  District 3    05/20/2020      08:39 AM  ...
# 26   Private Property Nuisance    05/20/2020      08:38 AM  ...
# 27                     Outside    05/20/2020      08:35 AM  ...
# 28   Trash on Private Property    05/20/2020      08:35 AM  ...
# 29        Other Property Issue    05/20/2020      08:23 AM  ...
# 30     Service Issue / Problem    05/20/2020      08:22 AM  ...
# 31                         Car    05/20/2020      08:18 AM  ...
# 32           Call Back Request    05/20/2020      08:10 AM  ...
# 33  Missed by Contractor South    05/20/2020      08:06 AM  ...
# 34           Other Light Issue    05/20/2020      08:05 AM  ...
# 35                  District 3    05/20/2020      07:38 AM  ...
# 36     Service Issue / Problem    05/20/2020      07:31 AM  ...
# 37        Other Property Issue    05/20/2020      07:20 AM  ...
# 38              Camera Request    05/20/2020      07:16 AM  ...
# 39     Right of Way LB Central    05/20/2020      07:15 AM  ...
# 40                       Loose    05/20/2020      07:11 AM  ...
# 41         Damaged - Emergency    05/20/2020      06:31 AM  ...
#
#     COUNCIL DISTRICT  POLICE DISTRICT PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0                1.0      Shoal Creek        86906  39.192537 -94.559330
# 1                3.0            Metro        50804  39.033228 -94.493439
# 2                2.0      Shoal Creek       227086  39.260214 -94.561275
# 3                2.0            North       164685  39.214514 -94.611094
# 4                6.0            Metro       106807  39.014424 -94.589893
# 5                3.0          Central        11694  39.104497 -94.553197
# 6                6.0            Metro       110158  39.001640 -94.606956
# 7                5.0            South        56446  38.951564 -94.515514
# 8                5.0            Metro       117216  38.981765 -94.562675
# 9                4.0          Central        39444  39.107328 -94.570900
# 10               4.0          Central        39444  39.107328 -94.570900
# 11               5.0            South        56304  38.955253 -94.510641
# 12               5.0            Metro       146925  39.025071 -94.570759
# 13               5.0            Metro       147164  39.021789 -94.569763
# 14               5.0            Metro       147165  39.021777 -94.570269
# 15               1.0      Shoal Creek        98624  39.307933 -94.540878
# 16               5.0            South        68592  38.956362 -94.493077
# 17               2.0      Shoal Creek       104275  39.269101 -94.559653
# 18               4.0          Central       140411  39.047119 -94.595106
# 19               5.0            Metro       145249  39.031293 -94.555256
# 20               3.0             East         7238  39.092696 -94.502784
# 21               5.0            Metro          492  39.014493 -94.529933
# 22               3.0             East        19319  39.083538 -94.531954
# 23               4.0          Central       142309  39.035740 -94.602297
# 24               1.0      Shoal Creek        86681  39.189202 -94.554422
# 25               6.0            Metro       107786  39.010000 -94.577409
# 26               4.0          Central       133515  39.051822 -94.572750
# 27               2.0      Shoal Creek       227087  39.260507 -94.561016
# 28               6.0            Metro       111180  39.004424 -94.583953
# 29               5.0            Metro        36243  39.026702 -94.552675
# 30               1.0      Shoal Creek       242008  39.257863 -94.541007
# 31               3.0             East        22811  39.067873 -94.527096
# 32               6.0            Metro       119992  38.989795 -94.602979
# 33               5.0            Metro        52765  39.001694 -94.498268
# 34               4.0          Central       129642  39.060503 -94.592531
# 35               5.0            South        56324  38.952485 -94.503579
# 36               5.0            Metro       116544  38.982017 -94.571196
# 37               1.0      Shoal Creek       220871  39.282316 -94.524756
# 38               3.0             East        21770  39.073048 -94.523277
# 39               3.0             East        21770  39.073048 -94.523277
# 40               6.0            Metro       113511  38.991981 -94.580619
# 41               4.0             East         7672  39.098057 -94.514916
#
#                                              CASE URL  \
# 0   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 1   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 2   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 3   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 4   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 5   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 6   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 7   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 8   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 9   http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 10  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 11  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 12  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 13  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 14  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 15  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 16  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 17  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 18  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 19  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 20  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 21  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 22  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 23  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 24  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 25  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 26  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 27  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 28  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 29  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 30  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 31  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 32  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 33  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 34  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 35  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 36  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 37  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 38  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 39  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 40  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
# 41  http://city.kcmo.org/kc/ActionCenterRequest/Ca...
#
#     30-60-90 Days Open Window  CREATION MONTH-DAY CREATION YEAR-MONTH-DAY  \
# 0                         0.0               05/20              2020/05/20
# 1                         0.0               05/20              2020/05/20
# 2                         0.0               05/20              2020/05/20
# 3                         0.0               05/20              2020/05/20
# 4                         0.0               05/20              2020/05/20
# 5                         0.0               05/20              2020/05/20
# 6                         0.0               05/20              2020/05/20
# 7                         0.0               05/20              2020/05/20
# 8                         0.0               05/20              2020/05/20
# 9                         0.0               05/20              2020/05/20
# 10                        0.0               05/20              2020/05/20
# 11                        0.0               05/20              2020/05/20
# 12                        0.0               05/20              2020/05/20
# 13                        0.0               05/20              2020/05/20
# 14                        0.0               05/20              2020/05/20
# 15                        0.0               05/20              2020/05/20
# 16                        0.0               05/20              2020/05/20
# 17                        0.0               05/20              2020/05/20
# 18                        0.0               05/20              2020/05/20
# 19                        0.0               05/20              2020/05/20
# 20                        0.0               05/20              2020/05/20
# 21                        0.0               05/20              2020/05/20
# 22                        0.0               05/20              2020/05/20
# 23                        0.0               05/20              2020/05/20
# 24                        0.0               05/20              2020/05/20
# 25                        0.0               05/20              2020/05/20
# 26                        0.0               05/20              2020/05/20
# 27                        0.0               05/20              2020/05/20
# 28                        0.0               05/20              2020/05/20
# 29                        0.0               05/20              2020/05/20
# 30                        0.0               05/20              2020/05/20
# 31                        0.0               05/20              2020/05/20
# 32                        0.0               05/20              2020/05/20
# 33                        0.0               05/20              2020/05/20
# 34                        0.0               05/20              2020/05/20
# 35                        0.0               05/20              2020/05/20
# 36                        0.0               05/20              2020/05/20
# 37                        0.0               05/20              2020/05/20
# 38                        0.0               05/20              2020/05/20
# 39                        0.0               05/20              2020/05/20
# 40                        0.0               05/20              2020/05/20
# 41                        0.0               05/20              2020/05/20
#
#      CREATION DATE-TIME
# 0   2020/05/20 09:26 AM
# 1   2020/05/20 09:23 AM
# 2   2020/05/20 09:22 AM
# 3   2020/05/20 09:21 AM
# 4   2020/05/20 09:20 AM
# 5   2020/05/20 09:17 AM
# 6   2020/05/20 09:17 AM
# 7   2020/05/20 09:15 AM
# 8   2020/05/20 09:15 AM
# 9   2020/05/20 09:12 AM
# 10  2020/05/20 09:11 AM
# 11  2020/05/20 09:09 AM
# 12  2020/05/20 09:09 AM
# 13  2020/05/20 09:08 AM
# 14  2020/05/20 09:05 AM
# 15  2020/05/20 09:00 AM
# 16  2020/05/20 08:58 AM
# 17  2020/05/20 08:57 AM
# 18  2020/05/20 08:56 AM
# 19  2020/05/20 08:53 AM
# 20  2020/05/20 08:49 AM
# 21  2020/05/20 08:46 AM
# 22  2020/05/20 08:44 AM
# 23  2020/05/20 08:42 AM
# 24  2020/05/20 08:40 AM
# 25  2020/05/20 08:39 AM
# 26  2020/05/20 08:38 AM
# 27  2020/05/20 08:35 AM
# 28  2020/05/20 08:35 AM
# 29  2020/05/20 08:23 AM
# 30  2020/05/20 08:22 AM
# 31  2020/05/20 08:18 AM
# 32  2020/05/20 08:10 AM
# 33  2020/05/20 08:06 AM
# 34  2020/05/20 08:05 AM
# 35  2020/05/20 07:38 AM
# 36  2020/05/20 07:31 AM
# 37  2020/05/20 07:20 AM
# 38  2020/05/20 07:16 AM
# 39  2020/05/20 07:15 AM
# 40  2020/05/20 07:11 AM
# 41  2020/05/20 06:31 AM
#
# [42 rows x 33 columns]

# %%
#Calculate Average 'DAYS TO CLOSE' Value for Each Date
avg_days_to_close = data.groupby(['CREATION MONTH-DAY', 'CREATION YEAR']).mean()
avg_days_to_close['DAYS TO CLOSE'] = avg_days_to_close['DAYS TO CLOSE'].round(2)
avg_days_to_close['30-60-90 Days Open Window'] = avg_days_to_close['30-60-90 Days Open Window'].round(2)
avg_days_to_close = avg_days_to_close.reset_index(level=['CREATION MONTH-DAY', 'CREATION YEAR'])
avg_days_to_close
# Out:
#      CREATION MONTH-DAY  CREATION YEAR       CASE ID  CREATION MONTH  \
# 0                 01/01           2011  2.011000e+09             1.0
# 1                 01/01           2012  2.012000e+09             1.0
# 2                 01/01           2013  2.013000e+09             1.0
# 3                 01/01           2014  2.014000e+09             1.0
# 4                 01/01           2015  2.015000e+09             1.0
# ...                 ...            ...           ...             ...
# 4826              12/31           2015  2.015154e+09            12.0
# 4827              12/31           2016  2.016158e+09            12.0
# 4828              12/31           2017  2.017162e+09            12.0
# 4829              12/31           2018  2.018171e+09            12.0
# 4830              12/31           2019  2.019211e+09            12.0
#
#       CLOSED MONTH  CLOSED YEAR  DAYS TO CLOSE      ZIP CODE  \
# 0         1.642857  2011.000000          24.57  64123.142857
# 1         1.100000  2012.000000          12.30  64128.800000
# 2         1.000000  2013.000000           2.33  64129.173913
# 3         1.400000  2014.080000          45.60  64125.960000
# 4         1.000000  2015.000000           5.06  64138.722222
# ...            ...          ...            ...           ...
# 4826      1.229522  2015.988055           7.18  64129.702218
# 4827      1.180851  2017.010638           3.82  64117.400000
# 4828      1.062500  2018.000000            NaN  64126.125000
# 4829      2.618343  2018.881657         380.33  64126.731988
# 4830      2.481050  2019.877551          10.01  64127.465374
#
#       COUNCIL DISTRICT   PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0             3.785714  132292.000000  39.086214 -94.558034
# 1             3.100000  112873.600000  39.090511 -94.537949
# 2             3.458333   97075.208333  39.084688 -94.553499
# 3             4.360000  126064.440000  38.804344 -95.324144
# 4             1.916667  163761.833333  39.198663 -94.525141
# ...                ...            ...        ...        ...
# 4826          4.952218  123290.161263  38.990578 -94.560930
# 4827          4.336842   97206.315789  39.057296 -94.575635
# 4828          3.125000   92732.875000  39.091532 -94.543044
# 4829          3.959654  109536.648415  39.060630 -94.552150
# 4830          3.481994   99671.049861  39.069683 -94.568937
#
#       30-60-90 Days Open Window
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 4826                        NaN
# 4827                      90.00
# 4828                        NaN
# 4829                      90.00
# 4830                      10.59
#
# [4831 rows x 13 columns]

# %%
#Show the Average Days to Close for Each Day
avg_days_to_close.dtypes
# Out:
# CREATION MONTH-DAY            object
# CREATION YEAR                  int64
# CASE ID                      float64
# CREATION MONTH               float64
# CLOSED MONTH                 float64
# CLOSED YEAR                  float64
# DAYS TO CLOSE                float64
# ZIP CODE                     float64
# COUNCIL DISTRICT             float64
# PARCEL ID NO                 float64
# LATITUDE                     float64
# LONGITUDE                    float64
# 30-60-90 Days Open Window    float64
# dtype: object

# %%
#Drop Unneeded Columns
avg_days_to_close = avg_days_to_close[['CREATION MONTH-DAY', 'CREATION YEAR','DAYS TO CLOSE', '30-60-90 Days Open Window']]
avg_days_to_close
# Out:
#      CREATION MONTH-DAY  CREATION YEAR  DAYS TO CLOSE  \
# 0                 01/01           2011          24.57
# 1                 01/01           2012          12.30
# 2                 01/01           2013           2.33
# 3                 01/01           2014          45.60
# 4                 01/01           2015           5.06
# ...                 ...            ...            ...
# 4826              12/31           2015           7.18
# 4827              12/31           2016           3.82
# 4828              12/31           2017            NaN
# 4829              12/31           2018         380.33
# 4830              12/31           2019          10.01
#
#       30-60-90 Days Open Window
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 4826                        NaN
# 4827                      90.00
# 4828                        NaN
# 4829                      90.00
# 4830                      10.59
#
# [4831 rows x 4 columns]

# %%
# get the data
citi_avg_df = avg_days_to_close
citi_avg_df_mod = citi_avg_df[['CREATION MONTH-DAY', 'CREATION YEAR', 'DAYS TO CLOSE', '30-60-90 Days Open Window']]


# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.citi_data
calls_avg = db.calls_avg

#Create Dictionary with Data
data_avg = citi_avg_df_mod.to_dict(orient='records')  # Here's our added param..

#Remove Existing Documents from Collection
calls_avg.remove()

#Insert Existing Documents into Collection
calls_avg.insert_many(data_avg)
# Out:
# C:\Users\bjros\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.

# %%
#Calculate Average 'DAYS TO CLOSE' Value for Each Date Filtered by 'STATUS' and 'SOURCE'
avg_days_to_close_filtered = data.groupby(['CREATION MONTH-DAY', 'CREATION YEAR', 'STATUS', 'SOURCE', 'DEPARTMENT']).mean()
avg_days_to_close_filtered['DAYS TO CLOSE'] = avg_days_to_close_filtered['DAYS TO CLOSE'].round(2)
avg_days_to_close_filtered['30-60-90 Days Open Window'] = avg_days_to_close_filtered['30-60-90 Days Open Window'].round(2)
avg_days_to_close_filtered = avg_days_to_close_filtered.reset_index(level=['CREATION MONTH-DAY', 'CREATION YEAR', 'STATUS', 'SOURCE', 'DEPARTMENT'])
avg_days_to_close_filtered
# Out:
#       CREATION MONTH-DAY  CREATION YEAR STATUS SOURCE      DEPARTMENT  \
# 0                  01/01           2011  RESOL  PHONE    Public Works
# 1                  01/01           2011  RESOL  PHONE  Water Services
# 2                  01/01           2011  RESOL    WEB          Health
# 3                  01/01           2011  RESOL    WEB             NHS
# 4                  01/01           2011  RESOL    WEB    Public Works
# ...                  ...            ...    ...    ...             ...
# 94550              12/31           2019  RESOL    WEB             NHS
# 94551              12/31           2019  RESOL    WEB       Northland
# 94552              12/31           2019  RESOL    WEB   Parks and Rec
# 94553              12/31           2019  RESOL    WEB    Public Works
# 94554              12/31           2019  RESOL    WEB  Water Services
#
#             CASE ID  CREATION MONTH  CLOSED MONTH  CLOSED YEAR  DAYS TO CLOSE  \
# 0      2.011000e+09             1.0      1.000000       2011.0           0.00
# 1      2.011000e+09             1.0      1.500000       2011.0          20.75
# 2      2.011000e+09             1.0      1.000000       2011.0           2.00
# 3      2.011000e+09             1.0      1.000000       2011.0           3.00
# 4      2.011000e+09             1.0      1.000000       2011.0           4.00
# ...             ...             ...           ...          ...            ...
# 94550  2.019211e+09            12.0      1.153846       2020.0          16.62
# 94551  2.019211e+09            12.0      1.166667       2020.0          15.12
# 94552  2.019211e+09            12.0      1.000000       2020.0           8.00
# 94553  2.019211e+09            12.0      1.200000       2020.0          15.40
# 94554  2.019211e+09            12.0      1.000000       2020.0           2.60
#
#            ZIP CODE  COUNCIL DISTRICT   PARCEL ID NO   LATITUDE  LONGITUDE  \
# 0      64118.000000          2.000000   96435.000000  39.212285 -94.594996
# 1      64126.750000          5.750000  162991.000000  38.965797 -94.576984
# 2      64105.000000          4.000000  234299.000000  39.098044 -94.583807
# 3      64119.000000          1.000000   85763.000000  39.197854 -94.513240
# 4      64126.000000          3.333333  201456.666667  39.123135 -94.551270
# ...             ...               ...            ...        ...        ...
# 94550  64124.153846          3.307692   84299.000000  39.080019 -94.529690
# 94551  64118.380952          1.071429   97964.000000  39.183907 -94.518232
# 94552  64115.500000          3.500000   98786.000000  39.077311 -94.557487
# 94553  64120.866667          2.266667   88139.800000  39.138121 -94.533273
# 94554  64111.000000          4.400000  156629.200000  39.022828 -94.584854
#
#        30-60-90 Days Open Window
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 94550                        NaN
# 94551                        NaN
# 94552                        NaN
# 94553                        NaN
# 94554                        NaN
#
# [94555 rows x 16 columns]

# %%
#Show the Average Days to Close for Each Day
avg_days_to_close_filtered.dtypes
# Out:
# CREATION MONTH-DAY            object
# CREATION YEAR                  int64
# STATUS                        object
# SOURCE                        object
# DEPARTMENT                    object
# CASE ID                      float64
# CREATION MONTH               float64
# CLOSED MONTH                 float64
# CLOSED YEAR                  float64
# DAYS TO CLOSE                float64
# ZIP CODE                     float64
# COUNCIL DISTRICT             float64
# PARCEL ID NO                 float64
# LATITUDE                     float64
# LONGITUDE                    float64
# 30-60-90 Days Open Window    float64
# dtype: object

# %%
#Drop Unneeded Columns
avg_days_to_close_filtered = avg_days_to_close_filtered[['CREATION MONTH-DAY', 'CREATION YEAR', 'STATUS', 'SOURCE', 'DEPARTMENT', 'DAYS TO CLOSE', '30-60-90 Days Open Window']]
avg_days_to_close_filtered
# Out:
#       CREATION MONTH-DAY  CREATION YEAR STATUS SOURCE      DEPARTMENT  \
# 0                  01/01           2011  RESOL  PHONE    Public Works
# 1                  01/01           2011  RESOL  PHONE  Water Services
# 2                  01/01           2011  RESOL    WEB          Health
# 3                  01/01           2011  RESOL    WEB             NHS
# 4                  01/01           2011  RESOL    WEB    Public Works
# ...                  ...            ...    ...    ...             ...
# 94550              12/31           2019  RESOL    WEB             NHS
# 94551              12/31           2019  RESOL    WEB       Northland
# 94552              12/31           2019  RESOL    WEB   Parks and Rec
# 94553              12/31           2019  RESOL    WEB    Public Works
# 94554              12/31           2019  RESOL    WEB  Water Services
#
#        DAYS TO CLOSE  30-60-90 Days Open Window
# 0               0.00                        NaN
# 1              20.75                        NaN
# 2               2.00                        NaN
# 3               3.00                        NaN
# 4               4.00                        NaN
# ...              ...                        ...
# 94550          16.62                        NaN
# 94551          15.12                        NaN
# 94552           8.00                        NaN
# 94553          15.40                        NaN
# 94554           2.60                        NaN
#
# [94555 rows x 7 columns]

# %%
# get the data
citi_avg_filtered_df = avg_days_to_close_filtered
citi_avg_filtered_df_mod = citi_avg_filtered_df[['CREATION MONTH-DAY', 'CREATION YEAR', 'STATUS', 'SOURCE', 'DEPARTMENT', 'DAYS TO CLOSE', '30-60-90 Days Open Window']]


# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.citi_data
calls_avg_filtered = db.calls_avg_filtered

#Create Dictionary with Data
data_avg_filtered = citi_avg_filtered_df_mod.to_dict(orient='records')  # Here's our added param..

#Remove Existing Documents from Collection
calls_avg_filtered.remove()

#Insert Existing Documents into Collection
calls_avg_filtered.insert_many(data_avg_filtered)
# Out:
# C:\Users\bjros\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
